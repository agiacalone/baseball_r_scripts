# %% [markdown]
# # MLB Standings
#
# Mirrors `get_standings.R`. Outputs all standings views for both leagues.

# %%
import sys
sys.path.insert(0, "..")
from src.baseball import *

# %%
# Parameters
SEASON = 2025

# %% [markdown]
# ## Combined AL + NL Standings

# %%
output_markdown(
    al_nl_combined_standings(SEASON),
    "../output/Standings/al_nl_combined_league_standings.md"
)

# %% [markdown]
# ## AL Combined Standings

# %%
output_markdown(
    combined_intraleague_standings(SEASON, league_id=103),
    "../output/Standings/al_combined_standings.md"
)

# %% [markdown]
# ## NL Combined Standings

# %%
output_markdown(
    combined_intraleague_standings(SEASON, league_id=104),
    "../output/Standings/nl_combined_standings.md"
)

# %% [markdown]
# ## AL Division Standings

# %%
output_markdown(
    standings(SEASON, league_id=103),
    "../output/Standings/al_standings.md"
)

# %% [markdown]
# ## NL Division Standings

# %%
output_markdown(
    standings(SEASON, league_id=104),
    "../output/Standings/nl_standings.md"
)

# %% [markdown]
# ## AL Wildcard Standings

# %%
output_markdown(
    wildcard_standings(SEASON, league_id=103),
    "../output/Standings/al_wc_standings.md"
)

# %% [markdown]
# ## NL Wildcard Standings

# %%
output_markdown(
    wildcard_standings(SEASON, league_id=104),
    "../output/Standings/nl_wc_standings.md"
)
